# %%
from docx import Document
import re
from tabulate import tabulate

# %% [markdown]
# from docx import Document: Imports the Document class from the python-docx library to read Word documents.
#
# import re: Imports the re module for regular expression operations.
#
# from tabulate import tabulate: Imports the tabulate function from the tabulate library to create nicely formatted tables.

# %%
def read_docx(file_path):
    doc = Document("C:/Users/Y Archana/Downloads/New Microsoft Word Document.docx")
    full_text = []
    for para in doc.paragraphs:
        full_text.append(para.text)
    return '\n'.join(full_text)

# %% [markdown]
# read_docx(file_path): This function reads the content of a .docx file specified by file_path.
# It iterates through each paragraph in the document and appends the text to a list.
# It then joins all the paragraphs into a single string with newline characters.

# %%
def classify_word(word):
    # List of common function words
    function_words = {
        'articles': {'the', 'a', 'an'},
        'prepositions': {'in', 'on', 'at', 'by', 'with', 'about', 'against', 'among', 'between', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'under', 'over', 'again', 'further', 'then', 'once'},
        'conjunctions': {'and', 'but', 'or', 'nor', 'so', 'for', 'yet'},
        'pronouns': {'he', 'she', 'it', 'they', 'we', 'you', 'I', 'me', 'him', 'her', 'us', 'them'},
        'determiners': {'this', 'that', 'these', 'those', 'my', 'your', 'his', 'her', 'its', 'our', 'their'},
        'modals': {'can', 'could', 'may', 'might', 'will', 'would', 'shall', 'should', 'must'},
        'auxiliary_verbs': {'am', 'is', 'are', 'was', 'were', 'being', 'been', 'be', 'have', 'has', 'had', 'do', 'does', 'did'}
    }

    if word in function_words['articles']:
        return 'article'
    elif word in function_words['prepositions']:
        return 'preposition'
    elif word in function_words['conjunctions']:
        return 'conjunction'
    elif word in function_words['pronouns']:
        return 'pronoun'
    elif word in function_words['determiners']:
        return 'determiner'
    elif word in function_words['modals']:
        return 'modal'
    elif word in function_words['auxiliary_verbs']:
        return 'auxiliary verb'
    elif word.endswith('ly'):
        return 'adverb'
    elif word.endswith('ing') or word.endswith('ed'):
        return 'verb'
    elif word.endswith('ous') or word.endswith('ful') or word.endswith('ic'):
        return 'adjective'
    else:
        return 'noun'  # Default assumption

# %% [markdown]
# classify_word(word): This function classifies a word based on simple heuristics into article,adverbs, verbs, adjectives, nouns, etc

# %%
def count_vowels_consonants(word):
    vowels = 'aeiou'
    num_vowels = sum(1 for char in word if char in vowels)
    num_consonants = len(word) - num_vowels
    return num_vowels, num_consonants

# %% [markdown]
# count_vowels_consonants(word): This function counts the number of vowels and consonants in a word and returns these counts.

# %%
def process_text_to_dict(text):
    word_dict = {}
    words = re.findall(r'\b\w+\b', text.lower())

    for word in words:
        word_type = classify_word(word)
        num_vowels, num_consonants = count_vowels_consonants(word)
        if word in word_dict:
            word_dict[word]['frequency'] += 1
        else:
            word_dict[word] = {
                'frequency': 1,
                'length': len(word),
                'type': word_type,
                'vowels': num_vowels,
                'consonants': num_consonants
            }
    return word_dict

# %% [markdown]
# process_text_to_dict(text): This function processes the input text and creates a dictionary where each key is a word, and the value is another dictionary containing its frequency, length, type, number of vowels, and number of consonants.
#
# words = re.findall(r'\b\w+\b', text.lower()): This line extracts all words from the text and converts them to lowercase.
#
# The loop then populates the word_dict with information about each word.

# %%
def get_word_attributes(word_dict):
    table_data = []
    for word, attrs in word_dict.items():
        table_data.append([word, attrs['frequency'], attrs['length'], attrs['type'], attrs['vowels'], attrs['consonants']])
    return table_data

# %% [markdown]
# get_word_attributes(word_dict): This function converts the dictionary into a list of lists suitable for creating a table. Each sublist contains the word and its attributes.

# %%
file_path = "C:/Users/Y Archana/Downloads/New Microsoft Word Document.docx"
doc_string = read_docx(file_path)
word_dict = process_text_to_dict(doc_string)
word_attributes_table = get_word_attributes(word_dict)

headers = ["Word", "Frequency", "Length", "Type", "Vowels", "Consonants"]
print(tabulate(word_attributes_table, headers, tablefmt="grid"))
# Out:
# +----------------+-------------+----------+----------------+----------+--------------+
# | Word           |   Frequency |   Length | Type           |   Vowels |   Consonants |
# +================+=============+==========+================+==========+==============+
# | thereby        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | mini           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | sizing         |           1 |        6 | verb           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | subjectivity   |           1 |       12 | noun           |        4 |            8 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | in             |          18 |        2 | preposition    |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | the            |          18 |        3 | article        |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | sense          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | of             |          11 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | potential      |           1 |        9 | noun           |        4 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | biases         |           1 |        6 | noun           |        3 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | and            |          10 |        3 | conjunction    |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | preconceptions |           1 |       14 | noun           |        5 |            9 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | latter         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | point          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | seems          |           2 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | especially     |           1 |       10 | adverb         |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | called         |           1 |        6 | verb           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | for            |           2 |        3 | conjunction    |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | given          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | delicate       |           1 |        8 | noun           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | stance         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | that           |           4 |        4 | determiner     |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | degrowth       |          11 |        8 | noun           |        2 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | takes          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | or             |           6 |        2 | conjunction    |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | to             |           8 |        2 | preposition    |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | take           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | towards        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | some           |           2 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | main           |           2 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | tenets         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | orthodox       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | mainstream     |           1 |       10 | noun           |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | economic       |           1 |        8 | adjective      |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | theory         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | cf             |           1 |        2 | noun           |        0 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | hickel         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2021           |           1 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | addition       |           1 |        8 | noun           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | we             |          12 |        2 | pronoun        |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | use            |           2 |        3 | noun           |        2 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | a              |           9 |        1 | article        |        1 |            0 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | network        |           2 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | analysis       |           4 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | approach       |           4 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | bibliometric   |           1 |       12 | adjective      |        5 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | data           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | through        |           2 |        7 | preposition    |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | co             |           2 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | authorships    |           1 |       11 | noun           |        4 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | identify       |           2 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | influential    |           1 |       11 | noun           |        5 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | authors        |           2 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | clusters       |           2 |        8 | noun           |        2 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | close          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | collaboration  |           1 |       13 | noun           |        6 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | this           |           1 |        4 | determiner     |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | mixed          |           2 |        5 | verb           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | methods        |           4 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | with           |           1 |        4 | preposition    |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | firm           |           1 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | base           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | multivariate   |           2 |       12 | noun           |        6 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | statistics     |           1 |       10 | noun           |        3 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | also           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | provides       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | an             |           2 |        2 | article        |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | alternative    |           1 |       11 | noun           |        5 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | other          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | recent         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | re             |           1 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | views          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | filed          |           1 |        5 | verb           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | have           |           2 |        4 | auxiliary verb |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | focused        |           1 |        7 | verb           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | exclusively    |           1 |       11 | adverb         |        4 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | on             |           2 |        2 | preposition    |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | qualitative    |           2 |       11 | noun           |        6 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | clustering     |           2 |       10 | verb           |        3 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | fitzpatrick    |           1 |       11 | noun           |        3 |            8 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | et             |           6 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | al             |           6 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2022           |           2 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | kallis         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2018           |           1 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | weiss          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | cattaneo       |           1 |        8 | noun           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2017           |           1 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | our            |           4 |        3 | determiner     |        2 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | paper          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | proceeds       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | as             |           6 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | follows        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | after          |           1 |        5 | preposition    |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | clarifying     |           1 |       10 | verb           |        3 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | key            |           2 |        3 | noun           |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | concepts       |           3 |        8 | noun           |        2 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | such           |           2 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | d              |           2 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | ecroissance    |           2 |       11 | noun           |        5 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | stationary     |           1 |       10 | noun           |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | economy        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | section        |           5 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2              |           2 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | give           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | detailed       |           1 |        8 | verb           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | overview       |           1 |        8 | noun           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | used           |           1 |        4 | verb           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 3              |           2 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 4              |           2 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | presents       |           1 |        8 | noun           |        2 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | results        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | before         |           1 |        6 | preposition    |        3 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | discuss        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | them           |           1 |        4 | pronoun        |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 5              |           1 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | draw           |           1 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | conclusions    |           1 |       11 | noun           |        4 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 6              |           1 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | clarify        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | most           |           1 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | important      |           1 |        9 | noun           |        3 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | relevant       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | discourse      |           1 |        9 | noun           |        4 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | following      |           2 |        9 | verb           |        3 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | particular     |           2 |       10 | noun           |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | follow         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | martinez       |           2 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | alier          |           2 |        5 | noun           |        3 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2010           |           1 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | distinguishing |           1 |       14 | verb           |        5 |            9 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | between        |           1 |        7 | preposition    |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | french         |           1 |        6 | noun           |        1 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | i              |           1 |        1 | noun           |        1 |            0 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | e              |           1 |        1 | noun           |        1 |            0 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | de             |           1 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | growth         |           2 |        6 | noun           |        1 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | la             |           1 |        2 | noun           |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | francaise      |           1 |        9 | noun           |        4 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | ecological     |           1 |       10 | noun           |        5 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | economics      |           2 |        9 | noun           |        4 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | here           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | review         |           1 |        6 | noun           |        3 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | first          |           1 |        5 | noun           |        1 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 15             |           1 |        2 | noun           |        0 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | years          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | research       |           3 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | published      |           2 |        9 | verb           |        3 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | academic       |           1 |        8 | adjective      |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | peer           |           2 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | reviewed       |           2 |        8 | verb           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | journals       |           2 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | specifically   |           1 |       12 | adverb         |        4 |            8 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | analyze        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | all            |           1 |        3 | noun           |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | referring      |           1 |        9 | verb           |        3 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | post           |           1 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | title          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | words          |           1 |        5 | noun           |        1 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | abstract       |           1 |        8 | noun           |        2 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | was            |           1 |        3 | auxiliary verb |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | from           |           1 |        4 | preposition    |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2008           |           1 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | english        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | language       |           1 |        8 | noun           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | journal        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | article        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | henceforth     |           1 |       10 | noun           |        3 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | literature1    |           1 |       11 | noun           |        5 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | using          |           1 |        5 | verb           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | address        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | four           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | gaps           |           1 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 1              |           1 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | inductive      |           1 |        9 | noun           |        4 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | statistical    |           1 |       11 | noun           |        4 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | procedure      |           2 |        9 | noun           |        4 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | within         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | literature     |           2 |       10 | noun           |        5 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | map            |           1 |        3 | noun           |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | conceptual     |           1 |       10 | noun           |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | landscape      |           1 |        9 | noun           |        3 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | provide        |           3 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | quantitative   |           1 |       12 | noun           |        6 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | account        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | which          |           2 |        5 | noun           |        1 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | cater          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | what           |           1 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | cluster        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | authorship     |           1 |       10 | noun           |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | field          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | distributional |           1 |       14 | noun           |        6 |            8 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | monetary       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | policy         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | proposals      |           1 |        9 | noun           |        3 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | brought        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | forward        |           1 |        7 | noun           |        2 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | is             |           2 |        2 | auxiliary verb |        1 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | itself         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | inspired       |           1 |        8 | verb           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | by             |           1 |        2 | preposition    |        0 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | plant          |           1 |        5 | noun           |        1 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | ecology        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | s              |           1 |        1 | noun           |        0 |            1 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | indictor       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | species        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | dufrene        |           1 |        7 | noun           |        3 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | legendre       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 1997           |           1 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | well           |           1 |        4 | noun           |        1 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | established    |           1 |       11 | verb           |        4 |            7 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | has            |           1 |        3 | auxiliary verb |        1 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | proven         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | suitable       |           1 |        8 | noun           |        4 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | relatively     |           1 |       10 | adverb         |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | young          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | scientific     |           1 |       10 | adjective      |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | fields         |           1 |        6 | noun           |        2 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | seen           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | deep           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | rise           |           1 |        4 | noun           |        2 |            2 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | popularity     |           1 |       10 | noun           |        4 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | ecosystem      |           1 |        9 | noun           |        3 |            6 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | services       |           1 |        8 | noun           |        3 |            5 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | abson          |           1 |        5 | noun           |        2 |            3 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | 2014           |           1 |        4 | noun           |        0 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | sustainability |           1 |       14 | noun           |        6 |            8 |
# +----------------+-------------+----------+----------------+----------+--------------+
# | drupp          |           1 |        5 | noun           |        1 |            4 |
# +----------------+-------------+----------+----------------+----------+--------------+

# %% [markdown]
# Reading the document: doc_string contains the text read from the specified Word document.
#
# Processing the text: word_dict is a dictionary with each word's details.
#
# Creating the table: word_attributes_table is a list of lists with each word and its attributes.
#
# Printing the table: The tabulate function prints the word attributes in a nicely formatted table with specified headers.
